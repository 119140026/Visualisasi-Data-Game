# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import statistics
import os

# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
import matplotlib.pyplot as plt

# %%
from pandas_profiling import ProfileReport
import pandas.util.testing as tm
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.

# %%
data_file_path = "/content/vgsales.csv"
companie_region_path = "/content/video-games-developers.csv"
total_sales_column = "Total_Sales"

# %%
primary_blue = "#496595"
primary_blue2 = "#85a1c1"
primary_blue3 = "#3f4d63"
primary_grey = "#c6ccd8"
primary_black = "#202022"
primary_bgcolor = "#f4f0ea"

primary_green = px.colors.qualitative.Plotly[2]

plt.rcParams['axes.facecolor'] = primary_bgcolor

colors = [primary_blue, primary_blue2, primary_blue3, primary_grey, primary_black, primary_bgcolor, primary_green]
sns.palplot(sns.color_palette(colors))

# %%
data_df = pd.read_csv(data_file_path)
data_df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
region_df = pd.read_csv(companie_region_path)
region_df.head()
# Out:
#         Developer    City Administrative division         Country  Est.  \
# 0        0verflow   Tokyo                     NaN           Japan  1997
# 1  11 bit studios  Warsaw    Masovian Voivodeship          Poland  2010
# 2      1C Company  Moscow                     NaN          Russia  1991
# 3     1-Up Studio   Tokyo                     NaN           Japan  2000
# 4        2K Czech    Brno                     NaN  Czech Republic  1997
#
#     Notable games, series or franchises  \
# 0      School DaysSummer DaysCross Days
# 1                             Frostpunk
# 2  King's Bounty: Warriors of the North
# 3                              Mother 3
# 4                         MafiaMafia II
#
#                                                Notes
# 0  Visual Novel brand (both developer and publisher)
# 1                          Indie developer/publisher
# 2  Game localization. The game development subsid...
# 3  Subsidiary of Nintendo. Formed by former emplo...
# 4  Former subsidiary of 2K Games; previously know...

# %%
df = pd.merge(data_df, region_df[['Developer', 'Country']], left_on='Publisher', right_on='Developer', how='left')
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Developer Country
# 0     41.49     29.02      3.77         8.46         82.74  Nintendo   Japan
# 1     29.08      3.58      6.81         0.77         40.24  Nintendo   Japan
# 2     15.85     12.88      3.79         3.31         35.82  Nintendo   Japan
# 3     15.75     11.01      3.28         2.96         33.00  Nintendo   Japan
# 4     11.27      8.89     10.22         1.00         31.37  Nintendo   Japan

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Developer',
#        'Country'],
#       dtype='object')

# %%
if 'Total_Shipped' in df.columns:
    df[total_sales_column] = df['Total_Shipped'].fillna(0) + df['Global_Sales'].fillna(0)
else:
    regions = ['NA', 'JP', 'EU', 'Other']
    region_sales_sufix = '_Sales'
    
    df[total_sales_column] = df['Global_Sales']

# %%
tdf = df.copy()
tdf = df[df['Year'].notna()] 
tdf = tdf.sort_values('Year', ascending=True)

# %%
platform_tdf = tdf.groupby(['Platform', 'Year']).agg({total_sales_column: 'sum'}).reset_index()
platform_tdf = platform_tdf.sort_values('Year', ascending=True)
platform_tdf.head(10)
# Out:
#    Platform    Year  Total_Sales
# 0      2600  1980.0        11.38
# 1      2600  1981.0        35.77
# 2      2600  1982.0        28.86
# 3      2600  1983.0         5.83
# 79      NES  1983.0        10.96
# 80      NES  1984.0        50.09
# 4      2600  1984.0         0.27
# 25       DS  1985.0         0.02
# 5      2600  1985.0         0.45
# 81      NES  1985.0        53.44

# %%
platform_tdf.to_excel('platform.xlsx')

# %% [markdown]
# # Data penjualan platform game di tahun 2016

# %%
platform_top_tdf = platform_tdf[platform_tdf['Year'].isin([2016, 2017, 2018, 2019])]
platform_top_tdf = platform_top_tdf[platform_top_tdf[total_sales_column] > platform_top_tdf[total_sales_column].sum() * 0.005]
platform_top_tdf['Year'] = platform_top_tdf['Year'].astype(str)

fig = px.bar(
    platform_top_tdf,
    x='Platform',
    y=total_sales_column,
    color='Year',
    barmode="group"
)
fig.update_layout(title="Total Penjualan Platform di Tahun 2016 (Juta)")
fig.update_xaxes(type='category')
fig.update_xaxes(categoryorder='category ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fcc10944-394c-4795-8fa2-2de2061a46a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcc10944-394c-4795-8fa2-2de2061a46a2")) {                    Plotly.newPlot(                        "fcc10944-394c-4795-8fa2-2de2061a46a2",                        [{"alignmentgroup":"True","hovertemplate":"Year=2016.0<br>Platform=%{x}<br>Total_Sales=%{y}<extra></extra>","legendgroup":"2016.0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2016.0","offsetgroup":"2016.0","orientation":"v","showlegend":true,"textposition":"auto","x":["PC","WiiU","PSV","PS4","PS3","3DS","X360","XOne"],"xaxis":"x","y":[2.6,3.29,3.4,39.25,2.59,6.6,0.83,12.37],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinew ...

# %% [markdown]
# # Data total penjualan platform game sampai tahun 2016

# %%
platform_sum_tdf = platform_tdf.groupby(['Platform']).agg({total_sales_column: 'sum'}).reset_index()
platform_sum_tdf = platform_sum_tdf[platform_sum_tdf[total_sales_column] > platform_sum_tdf[total_sales_column].sum() * 0.03]

fig = px.bar(
    platform_sum_tdf,
    x='Platform',
    y=total_sales_column,
)
fig.update_layout(title="Total Penjualan Platform (Juta)")
fig.update_xaxes(type='category')
fig.update_xaxes(categoryorder='category ascending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9c8c7b59-5474-443e-9464-ca8565faa120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c8c7b59-5474-443e-9464-ca8565faa120")) {                    Plotly.newPlot(                        "9c8c7b59-5474-443e-9464-ca8565faa120",                        [{"alignmentgroup":"True","hovertemplate":"Platform=%{x}<br>Total_Sales=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["DS","GBA","PS","PS2","PS3","PS4","PSP","Wii","X360"],"xaxis":"x","y":[818.9599999999999,313.56,727.39,1233.46,949.35,278.1,291.71,909.81,969.61],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"ou ...

# %%
platform_tmp_tdf = tdf.groupby(['Platform', 'Year']).agg({total_sales_column: ['sum', 'count']})

# %% [markdown]
# # Data penjualan berdasarkan genre

# %%
if 'Total_Shipped' in df.columns:
    regions = ['NA', 'JP', 'PAL', 'Other']
else:
    regions = ['NA', 'JP', 'EU', 'Other']

region_sales_sufix = '_Sales'
regions_agg = {}

for region in regions:
    regions_agg[region + region_sales_sufix] = 'sum'

regions_agg[total_sales_column] = 'sum'
regions_agg
# Out:
# {'EU_Sales': 'sum',
#  'JP_Sales': 'sum',
#  'NA_Sales': 'sum',
#  'Other_Sales': 'sum',
#  'Total_Sales': 'sum'}

# %%
geo_tdf = tdf.groupby(['Year']).agg(regions_agg).reset_index()
geo_tdf = geo_tdf.sort_values('Year', ascending=True)
geo_tdf.head(10)
# Out:
#      Year  NA_Sales  JP_Sales  EU_Sales  Other_Sales  Total_Sales
# 0  1980.0     10.59      0.00      0.67         0.12        11.38
# 1  1981.0     33.40      0.00      1.96         0.32        35.77
# 2  1982.0     26.92      0.00      1.65         0.31        28.86
# 3  1983.0      7.76      8.10      0.80         0.14        16.79
# 4  1984.0     33.28     14.27      2.10         0.70        50.36
# 5  1985.0     33.73     14.56      4.74         0.92        53.94
# 6  1986.0     12.50     19.81      2.84         1.93        37.07
# 7  1987.0      8.46     11.63      1.41         0.20        21.74
# 8  1988.0     23.87     15.76      6.59         0.99        47.22
# 9  1989.0     45.15     18.36      8.44         1.50        73.45

# %%
genre_tdf = tdf.groupby(['Genre']).agg(regions_agg)
genre_tdf = genre_tdf.sort_values(total_sales_column, ascending=False)
genre_tdf.head()
# Out:
#               NA_Sales  JP_Sales  EU_Sales  Other_Sales  Total_Sales
# Genre
# Action          861.80    158.66    516.48       184.92      1722.88
# Sports          670.09    134.76    371.34       132.65      1309.24
# Shooter         575.16     38.18    310.45       101.90      1026.20
# Role-Playing    326.50    350.29    187.58        59.38       923.84
# Platform        445.99    130.65    200.67        51.51       829.15

# %%
genre_tdf.to_excel('genre.xlsx')

# %%
genre_total_tdf = genre_tdf.reset_index().sort_values(total_sales_column, ascending=False)
genre_tops = list(genre_total_tdf.loc[genre_total_tdf[total_sales_column] > genre_total_tdf[total_sales_column].sum() * 0.03, 'Genre'])
genre_tops
# Out:
# ['Action',
#  'Sports',
#  'Shooter',
#  'Role-Playing',
#  'Platform',
#  'Misc',
#  'Racing',
#  'Fighting',
#  'Simulation']

# %%
genre_tops_df = tdf[tdf['Genre'].isin(genre_tops)]

fig  = go.Figure()
fig.add_trace(go.Pie(
    labels=genre_tops_df['Genre'], 
    values=genre_tops_df[total_sales_column], 
    pull=[0, 0, 0.1, 0.05, 0, 0, 0.05, 0, 0.05],
))

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(title="Total Penjualan Game Berdasarkan Genre")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7120d23d-fd64-4910-b5be-f45d8be3a0d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7120d23d-fd64-4910-b5be-f45d8be3a0d9")) {                    Plotly.newPlot(                        "7120d23d-fd64-4910-b5be-f45d8be3a0d9",                        [{"labels":["Misc","Fighting","Action","Misc","Misc","Misc","Shooter","Shooter","Sports","Action","Action","Action","Shooter","Action","Shooter","Platform","Action","Shooter","Action","Sports","Simulation","Shooter","Sports","Shooter","Action","Action","Racing","Action","Action","Shooter","Action","Platform","Action","Action","Action","Shooter","Action","Shooter","Action","Action","Action","Action","Sports","Action","Action","Action","Sports","Action","Shooter","Shooter","Action","Action","Platform","Action","Platform","Platform","Action","Action","Platform","Shooter","Misc","Action","Racing","Platform","Action","Shooter","Action","Action","Sports","Shooter","Action","Action","Action","Action","Action","Action","Platform","Shooter","Action","Shooter","Sports","Action","Action","Racing","Action","Action","Action","Platform","Action","Action","Misc","Action","Sports","Platform","Platform","Action","Platform","Action","Shooter","Action","Platform","Sports","Racing","Racing","Shooter","Sports","Shooter","Racing","Action","Platform","Shooter","Misc","Fighting","Sports","Platform","Platform","Platform","Action","Simulation","Platform","Action","Shooter","Sports","Action","Role-Playing","Platform","Platform","Sports","Shooter","Action","Sports","Platform","Action","Action","Racing","Action","Shooter","Platform","Platform","Shooter","Platform","Shooter","Action","Role-Playing","Role-Playing","Role-Playing","Platform","Shooter","Fighting","Sports","Platform","Fighting","Sports","Action","Shooter","Sports","Sports","Action","Racing","Platform","Platform","Platform","Platform","Action","Role-Playing","Action","Simulation","Sports","Role-Playing","Sports","Shooter","Role-Playing","Sports","Role-Playing","Role-Playing","Shooter","Sports","Action","Platform","Action","Sports","Misc","Platform","Platform","Role-Playing","Sports","Platform","Role-Playing","Sports","Racing","Racing","Sports","Simulation","Platform","Action","Action","Action","Platform","Platform","Sports","Sports","Sports","Platform","Action","Simulation","Shooter","Racing","Role-Playing","Role-Playing","Action","Action","Role-Playing","Shooter","Platform","Sports","Role-Playing","Sports","Shooter","Misc","Role-Playing","Platform","Sports","Action","Simulation","Action","Platform","Fighting","Sports","Platform","Role-Playing","Misc","Simulation","Action","Sports","Fighting","Racing","Shooter","Role-Playing","Misc","Platform","Fighting","Role-Playing","Fighting","Role-Playing","Shooter","Shooter","Platform","Sports","Sports","Platform","Fighting","Fighting","Platform","Fighting","Sports","Role-Playing","Fighting","Platform","Platform","Racing","Role-Playing","Role-Playing","Platform","Shooter","Fighting","Fighting","Role-Playing","Platform","Sports","Platform","Role-Playing","Sports","Sports","Sports","Role-Playing","Platform","Fighting","Fighting","Platform","Simulation","Racing","Sports","Role-Playing","Platform","Fighting","Fighting","Fighting","Platform","Misc","Fighting","Fighting","Shooter","Fighting","Sports","Action","Action","Sports","Platform","Action","Role-Playing","Action","Sports","Platform","Racing","Misc","Misc","Action","Fighting","Platform","Role-Playing","Action","Platform","Sports","Role-Playing","Role-Playing","Sports","Misc","Platform","Misc","Role-Playing","Platform","Fighting","Racing","Sports","Shooter","Sports","Racing","Platform","Action","Fighting","Role-Playing","Sports","Fighting","Role-Playing","Racing","Role-Pl ...

# %% [markdown]
# # Data penjualan dengan menggunakan diagram Sunburst untuk melihat data berdasarkan platform dan genre

# %%
platform_tops = ['PS4', 'PSV', 'XOne', 'PC']
plat_genre_df = tdf[(tdf['Genre'].isin(genre_tops[:4])) & (tdf['Platform'].isin(platform_tops[:4]))]

fig = px.sunburst(plat_genre_df, path=['Genre', 'Platform'], values=total_sales_column)
fig.update_layout(title="Perbandingan Penjualan Game Berdasarkan Genre dan Platform (Juta)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b2a72851-fa87-4686-b853-857788eaea13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2a72851-fa87-4686-b853-857788eaea13")) {                    Plotly.newPlot(                        "b2a72851-fa87-4686-b853-857788eaea13",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Total_Sales=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Action/PC","Role-Playing/PC","Shooter/PC","Sports/PC","Action/PS4","Role-Playing/PS4","Shooter/PS4","Sports/PS4","Action/PSV","Role-Playing/PSV","Shooter/PSV","Sports/PSV","Action/XOne","Role-Playing/XOne","Shooter/XOne","Sports/XOne","Action","Role-Playing","Shooter","Sports"],"labels":["PC","PC","PC","PC","PS4","PS4","PS4","PS4","PSV","PSV","PSV","PSV","XOne","XOne","XOne","XOne","Action","Role-Playing","Shooter","Sports"],"name":"","parents":["Action","Role-Playing","Shooter","Sports","Action","Role-Playing","Shooter","Sports","Action","Role-Playing","Shooter","Sports","Action","Role-Playing","Shooter","Sports","","","",""],"values":[30.67,47.37,43.44,12.01,87.06,25.77,75.32,50.07,20.01,13.09,4.57,4.88,33.79,9.479999999999999,51.61,23.97,171.53,95.71,174.94,90.92999999999999],"type":"sunburst"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":" ...
